# %% [markdown]
# ## TODO: distinguish return journeies

# %%
import geopandas as gpd
import pandas as pd
from geographiclib.geodesic import Geodesic
from shapely.geometry import MultiLineString
from shapely.geometry import Point

import folium

# %%
airline_routes = pd.read_json('./data/airline-route-data/airline_routes.json',orient='index')
airline_routes.head()
# Out:
#     city_name continent           country country_code  \
# AAA      Anaa        OC  French Polynesia           PF
# AAD     Adado        AF           Somalia           SO
# AAE    Annaba        AF           Algeria           DZ
# AAK   Aranuka        OC          Kiribati           KI
# AAL   Aalborg        EU           Denmark           DK
#
#                      display_name  elevation iata  icao   latitude  \
# AAA  Anaa (AAA), French Polynesia       23.0  AAA  NTGA -17.355648
# AAD          Adado (AAD), Somalia     1005.0  AAD  None   6.095833
# AAE         Annaba (AAE), Algeria       16.0  AAE  DABB  36.821392
# AAK       Aranuka (AAK), Kiribati        0.0  AAK  NGUK   0.166667
# AAL        Aalborg (AAL), Denmark       10.0  AAL  EKYT  57.086551
#
#       longitude             name  \
# AAA -145.509130     Anaa Airport
# AAD   46.637500    Adado Airport
# AAE    7.811857           Annaba
# AAK  173.583333  Aranuka Airport
# AAL    9.872241          Aalborg
#
#                                                 routes           timezone
# AAA  [{'carriers': [{'iata': 'VT', 'name': 'Air Tah...     Pacific/Tahiti
# AAD  [{'carriers': [], 'iata': 'MGQ', 'km': 474, 'm...   Africa/Mogadishu
# AAE  [{'carriers': [{'iata': 'AH', 'name': 'Air Alg...     Africa/Algiers
# AAK  [{'carriers': [{'iata': 'IK', 'name': 'Air Kir...     Pacific/Tarawa
# AAL  [{'carriers': [{'iata': 'D8', 'name': 'Norwegi...  Europe/Copenhagen

# %%
my_flights_df = pd.read_excel('./data/Flight History.xlsx')
my_flights_df.head()
# Out:
#         Date Flight Number Departure Arrival     Aircraft  \
# 0 2015-07-28        ZH9250       XIY     SZX  Airbus A320
# 1 2015-08-01        ZH9249       SZX     XIY  Airbus A320
# 2 2019-07-25        JD5343       XIY     DLC  Airbus A319
# 3 2019-07-30        JD5344       DLC     XIY  Airbus A320
# 4 2022-11-03        HO1212       XIY     SHA  Airbus A320
#
#   Aircraft Registration    Class
# 0                 B6740  Economy
# 1                 B6570  Economy
# 2                 B6245  Economy
# 3                 B6958  Economy
# 4                 B1681  Economy

# %%
my_flights_df['Departure Latitude'] = airline_routes['latitude'][my_flights_df.Departure].values
my_flights_df['Departure Longitude'] = airline_routes['longitude'][my_flights_df.Departure].values
my_flights_df['Arrival Latitude'] = airline_routes['latitude'][my_flights_df.Arrival].values
my_flights_df['Arrival Longitude'] = airline_routes['longitude'][my_flights_df.Arrival].values
my_flights_df['Route'] = my_flights_df.Departure + '->' +my_flights_df.Arrival

# %%
def geodesic(lat1, lon1, lat2, lon2):
    inverse = Geodesic.WGS84.Inverse(lat1, lon1, lat2, lon2)
    dist = inverse['s12']/1000
    steps = int(dist /50)
    linestrings = []
    coordinates = []

    for i in range(0, steps + 1):
        direct = Geodesic.WGS84.Direct(inverse['lat1'], inverse['lon1'], inverse['azi1'], (i / float(steps)) * inverse['s12'])
        if len(coordinates) > 0:
            if (coordinates[-1][0] < -90 and direct['lon2'] > 90) or (coordinates[-1][0] > 90 and direct['lon2'] < -90):
                linestrings.append(coordinates)
                coordinates = []
        coordinates.append((direct['lon2'], direct['lat2']))

    linestrings.append(coordinates)
    return MultiLineString(linestrings)


def geodesic_with_perturbation(lat1, lon1, lat2, lon2, perturbation_factor=0.0001):
    # Calculate the inverse solution (distance, azimuth, etc.)
    inverse = Geodesic.WGS84.Inverse(lat1, lon1, lat2, lon2)
    dist = inverse['s12'] / 1000  # Convert meters to kilometers
    steps = int(dist / 50)  # One step every 50 km
    linestrings = []
    coordinates = []

    for i in range(0, steps + 1):
        # Generate points along the great circle
        direct = Geodesic.WGS84.Direct(
            inverse['lat1'],
            inverse['lon1'],
            inverse['azi1'],
            (i / float(steps)) * inverse['s12']
        )

        # Introduce a perturbation at the midpoint to differentiate direction
        if i == steps // 2:  # Midpoint
            direct['lat2'] += perturbation_factor if lat1 < lat2 else -perturbation_factor

        # Handle crossing the dateline
        if len(coordinates) > 0:
            if (coordinates[-1][0] < -90 and direct['lon2'] > 90) or (coordinates[-1][0] > 90 and direct['lon2'] < -90):
                linestrings.append(coordinates)
                coordinates = []

        # Add the point to the coordinates
        coordinates.append((direct['lon2'], direct['lat2']))

    # Add the last segment
    linestrings.append(coordinates)

    return MultiLineString(linestrings)

# %%
geometry = my_flights_df.apply(lambda x: geodesic(x['Departure Latitude'], x['Departure Longitude'], x['Arrival Latitude'], x['Arrival Longitude']), axis=1)

# %%
my_flights_df['Distance'] = my_flights_df.apply(lambda x: Geodesic.WGS84.Inverse(x['Departure Latitude'], x['Departure Longitude'], x['Arrival Latitude'], x['Arrival Longitude'])['s12']/1000, axis=1).astype(int).astype(str) + ' km'

# %%
n_airports = (my_flights_df.groupby('Departure').count().iloc[:,0]).add(my_flights_df.groupby('Arrival').count().iloc[:,0], fill_value=0).astype(int)

# %%
my_airports = airline_routes.loc[n_airports.index].drop(columns='routes')

# %%
my_airports['No. visit'] = n_airports

# %%
geometry_airports = my_airports.apply(lambda x: Point(x['longitude'], x['latitude']), axis=1)

# %%
my_airports_gdf = gpd.GeoDataFrame(data=my_airports, geometry=geometry_airports, crs=4326)

# %%
n_route = my_flights_df.groupby('Route').count().iloc[:,0]

# %%
my_flights_df['No. flight'] = my_flights_df.Route.apply(lambda x: n_route[x])

# %%
my_airports_gdf['Name'] = my_airports_gdf.name

# %%
m = folium.Map(location=[40,  70], zoom_start=3,world_copy_jump=True, tiles='cartodb voyager')

folium.GeoJson(
    my_airports_gdf,
    name="Airports",
    marker=folium.CircleMarker(radius=20, fill_color="orangered", fill_opacity=0.6, color="black", weight=1),
    tooltip=folium.GeoJsonTooltip(fields=["Name",'No. visit']),
    style_function=lambda x: {
        "fillColor": 'orange',
        "radius": (x['properties']['No. visit'])*1 + 3,
    },
    highlight_function=lambda x: {"fillOpacity": 1},
).add_to(m)

my_flights_gdf = gpd.GeoDataFrame(data=my_flights_df, geometry=geometry, crs=4326)



folium.GeoJson(data=my_flights_gdf.iloc[:,1:],
               tooltip=folium.GeoJsonTooltip(fields=["Route", "No. flight"]),
               style_function=lambda x: {
                   "color":"black",
                   "weight": (x['properties']['No. flight']) *1.5,
               }
               
               ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ad27dd662b6b0a96fa34c02124c1de8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ad27dd662b6b0a96fa34c02124c1de8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ad27dd662b6b0a96fa34c02124c1de8 = L.map(
#                 &quot;map_9ad27dd662b6b0a96fa34c02124c1de8&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     worldCopyJump: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_762d2e12c02993ad43e2eccbf0acb5d6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/rastertiles/voyager/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_762d2e12c02993ad43e2eccbf0acb5d6.addTo(map_9ad27dd662b6b0a96fa34c02124c1de8);
#
#
#         function geo_json_5ebfa7f8616666b49aedfee364c311b1_styler(feature) {
#             switch(feature.id) {
#                 case &quot;BUD&quot;: case &quot;HGH&quot;: case &quot;MAD&quot;: case &quot;NAP&quot;: case &quot;SHE&quot;: case &quot;VIE&quot;: case &quot;ZUH&quot;:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;, &quot;radius&quot;: 4};
#                 case &quot;CAN&quot;:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;, &quot;radius&quot;: 7};
#                 case &quot;DLC&quot;: case &quot;PKX&quot;: case &quot;SZX&quot;:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;, &quot;radius&quot;: 6};
#                 case &quot;GVA&quot;: case &quot;SHA&quot;:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;, &quot;radius&quot;: 10};
#                 case &quot;IST&quot;:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;, &quot;radius&quot;: 9};
#                 case &quot;LIS&quot;: case &quot;NCE&quot;: case &quot;PEK&quot;: case &quot;PVG&quot;:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;, &quot;radius&quot;: 5};
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;, &quot;radius&quot;: 21};
#             }
#         }
#         function geo_json_5ebfa7f8616666b49aedfee364c311b1_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 1};
#             }
#         }
#         function geo_json_5ebfa7f8616666b49aedfee364c311b1_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orangered&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 1};
#
#             let style = geo_json_5ebfa7f8616666b49aedfee364c311b1_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5ebfa7f8616666b49aedfee364c311b1_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5ebfa7f8616666b49aedfee364c311b1.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5ebfa7f8616666b49aedfee364c311b1_highlighter(

# %%
# m.save('my_flight_log.html')

# %%
my_flights_df
# Out:
#          Date Flight Number Departure Arrival     Aircraft  \
# 0  2015-07-28        ZH9250       XIY     SZX  Airbus A320
# 1  2015-08-01        ZH9249       SZX     XIY  Airbus A320
# 2  2019-07-25        JD5343       XIY     DLC  Airbus A319
# 3  2019-07-30        JD5344       DLC     XIY  Airbus A320
# 4  2022-11-03        HO1212       XIY     SHA  Airbus A320
# 5  2022-11-09        9C8947       SHA     XIY  Airbus A321
# 6  2023-04-13        CZ3762       XIY     ZUH   Boeing 737
# 7  2023-04-17        CZ6567       CAN     HGH  Airbus A350
# 8  2023-04-24        CZ3548       SHA     CAN  Airbus A350
# 9  2023-04-24        CZ3215       CAN     XIY   Boeing 737
# 10 2023-05-09        CZ8830       XIY     PKX  Airbus A320
# 11 2023-06-19        CZ6938       XIY     DLC  Airbus A321
# 12 2023-06-26        CZ6415       SHE     XIY  Airbus A320
# 13 2023-07-04        CZ8830       XIY     PKX  Airbus A321
# 14 2023-07-06        CZ6948       PKX     XIY  Airbus A321
# 15 2023-08-15        CZ6622       XIY     SZX  Airbus A330
# 16 2023-08-17          TK73       CAN     IST   Boeing 777
# 17 2023-08-18        TK1917       IST     GVA  Airbus A321
# 18 2024-02-07        LX2092       GVA     LIS  Airbus A220
# 19 2024-02-09        UX1152       LIS     MAD   Boeing 737
# 20 2024-04-05        U24223       NAP     GVA  Airbus A320
# 21 2024-07-08        TK1920       GVA     IST  Airbus A330
# 22 2024-07-09          TK88       IST     PEK   Boeing 777
# 23 2024-07-09        MU5124       PEK     SHA  Airbus A330
# 24 2024-07-26        HO1235       SHA     XIY  Airbus A321
# 25 2024-08-05        MU2336       XIY     SHA   COMAC C919
# 26 2024-08-31        MU2152       SHA     XIY   COMAC C919
# 27 2024-09-04        CA8326       XIY     PVG  Airbus A321
# 28 2024-09-04          TK27       PVG     IST   Boeing 777
# 29 2024-09-05        TK1921       IST     GVA  Airbus A321
# 30 2024-10-22        U21565       GVA     BUD  Airbus A320
# 31 2024-10-27        W42849       VIE     NCE  Airbus A321
# 32 2024-10-27        U21328       NCE     GVA  Airbus A320
#
#    Aircraft Registration    Class  Departure Latitude  Departure Longitude  \
# 0                  B6740  Economy           34.438416           108.760946
# 1                  B6570  Economy           22.639444           113.810833
# 2                  B6245  Economy           34.438416           108.760946
# 3                  B6958  Economy           38.961020           121.539991
# 4                  B1681  Economy           34.438416           108.760946
# 5                  B30EU  Economy           31.197790           121.333473
# 6                  B6067  Economy           34.438416           108.760946
# 7                  B309W  Economy           23.387862           113.297340
# 8                  B32AV  Economy           31.197790           121.333473
# 9                  B2695  Economy           23.387862           113.297340
# 10                 B6977  Economy           34.438416           108.760946
# 11                 B2287  Economy           34.438416           108.760946
# 12                 B301G  Economy           41.634992           123.485731
# 13                 B323F  Economy           34.438416           108.760946
# 14                 B1843  Economy           39.508611           116.410833
# 15                 B8360  Economy           34.438416           108.760946
# 16                 TCLJG  Economy           23.387862           113.297340
# 17                 TCLSZ  Economy           41.260278            28.741944
# 18                 HBJBE  Economy           46.229634             6.105774
# 19                 ECMPS  Economy           38.770043            -9.128165
# 20                 OEIVF  Economy           40.886111            14.291667
# 21                 TCLOB  Economy           46.229634             6.105774
# 22                 TCLJA  Economy           41.260278            28.741944
# 23                 B6097  Economy           40.078538           116.587095
# 24                 B8956  Economy           31.197790           121.333473
# 25                 B919A  Economy           34.438416           108.760946
# 26                 B919A  Economy           31.197790           121.333473
# 27                 B8595  Economy           34.438416           108.760946
# 28                 TCLJG  Economy           31.143333           121.805278
# 29                 TCLSZ  Economy           41.260278            28.741944
# 30                 HBJYA  Economy           46.229634             6.105774
# 31                 HALGM  Economy           48.119720            16.563583
# 32                 HBJXB  Economy           43.660488             7.205232
#
#     Arrival Latitude  Arrival Longitude     Route Distance  No. flight
# 0          22.639444         113.810833  XIY->SZX  1397 km           2
# 1          34.438416         108.760946  SZX->XIY  1397 km           1
# 2          38.961020         121.539991  XIY->DLC  1245 km           2
# 3          34.438416         108.760946  DLC->XIY  1245 km           1
# 4          31.197790         121.333473  XIY->SHA  1229 km           2
# 5          34.438416         108.760946  SHA->XIY  1229 km           3
# 6          22.011788         113.370601  XIY->ZUH  1449 km           1
# 7          30.236934         120.432356  CAN->HGH  1038 km           1
# 8          23.387862         113.297340  SHA->CAN  1174 km           1
# 9          34.438416         108.760946  CAN->XIY  1301 km           1
# 10         39.508611         116.410833  XIY->PKX   882 km           2
# 11         38.961020         121.539991  XIY->DLC  1245 km           2
# 12         34.438416         108.760946  SHE->XIY  1516 km           1
# 13         39.508611         116.410833  XIY->PKX   882 km           2
# 14         34.438416         108.760946  PKX->XIY   882 km           1
# 15         22.639444         113.810833  XIY->SZX  1397 km           2
# 16         41.260278          28.741944  CAN->IST  7897 km           1
# 17         46.229634           6.105774  IST->GVA  1897 km           2
# 18         38.770043          -9.128165  GVA->LIS  1497 km           1
# 19         40.490270          -3.564479  LIS->MAD   514 km           1
# 20         46.229634           6.105774  NAP->GVA   887 km           1
# 21         41.260278          28.741944  GVA->IST  1897 km           1
# 22         40.078538         116.587095  IST->PEK  7078 km           1
# 23         31.197790         121.333473  PEK->SHA  1074 km           1
# 24         34.438416         108.760946  SHA->XIY  1229 km           3
# 25         31.197790         121.333473  XIY->SHA  1229 km           2
# 26         34.438416         108.760946  SHA->XIY  1229 km           3
# 27         31.143333         121.805278  XIY->PVG  1274 km           1
# 28         41.260278          28.741944  PVG->IST  8039 km           1
# 29         46.229634           6.105774  IST->GVA  1897 km           2
# 30         47.433037          19.261621  GVA->BUD  1011 km           1
# 31         43.660488           7.205232  VIE->NCE   878 km           1
# 32         46.229634           6.105774  NCE->GVA   298 km           1

# %%
my_flights_df.columns
# Out:
# Index(['Date', 'Flight Number', 'Departure', 'Arrival', 'Aircraft',
#        'Aircraft Registration', 'Class', 'Departure Latitude',
#        'Departure Longitude', 'Arrival Latitude', 'Arrival Longitude', 'Route',
#        'Distance', 'No. flight'],
#       dtype='object')

# %%
my_flights_df
# Out:
#          Date Flight Number Departure Arrival     Aircraft  \
# 0  2015-07-28        ZH9250       XIY     SZX  Airbus A320
# 1  2015-08-01        ZH9249       SZX     XIY  Airbus A320
# 2  2019-07-25        JD5343       XIY     DLC  Airbus A319
# 3  2019-07-30        JD5344       DLC     XIY  Airbus A320
# 4  2022-11-03        HO1212       XIY     SHA  Airbus A320
# 5  2022-11-09        9C8947       SHA     XIY  Airbus A321
# 6  2023-04-13        CZ3762       XIY     ZUH   Boeing 737
# 7  2023-04-17        CZ6567       CAN     HGH  Airbus A350
# 8  2023-04-24        CZ3548       SHA     CAN  Airbus A350
# 9  2023-04-24        CZ3215       CAN     XIY   Boeing 737
# 10 2023-05-09        CZ8830       XIY     PKX  Airbus A320
# 11 2023-06-19        CZ6938       XIY     DLC  Airbus A321
# 12 2023-06-26        CZ6415       SHE     XIY  Airbus A320
# 13 2023-07-04        CZ8830       XIY     PKX  Airbus A321
# 14 2023-07-06        CZ6948       PKX     XIY  Airbus A321
# 15 2023-08-15        CZ6622       XIY     SZX  Airbus A330
# 16 2023-08-17          TK73       CAN     IST   Boeing 777
# 17 2023-08-18        TK1917       IST     GVA  Airbus A321
# 18 2024-02-07        LX2092       GVA     LIS  Airbus A220
# 19 2024-02-09        UX1152       LIS     MAD   Boeing 737
# 20 2024-04-05        U24223       NAP     GVA  Airbus A320
# 21 2024-07-08        TK1920       GVA     IST  Airbus A330
# 22 2024-07-09          TK88       IST     PEK   Boeing 777
# 23 2024-07-09        MU5124       PEK     SHA  Airbus A330
# 24 2024-07-26        HO1235       SHA     XIY  Airbus A321
# 25 2024-08-05        MU2336       XIY     SHA   COMAC C919
# 26 2024-08-31        MU2152       SHA     XIY   COMAC C919
# 27 2024-09-04        CA8326       XIY     PVG  Airbus A321
# 28 2024-09-04          TK27       PVG     IST   Boeing 777
# 29 2024-09-05        TK1921       IST     GVA  Airbus A321
# 30 2024-10-22        U21565       GVA     BUD  Airbus A320
# 31 2024-10-27        W42849       VIE     NCE  Airbus A321
# 32 2024-10-27        U21328       NCE     GVA  Airbus A320
#
#    Aircraft Registration    Class  Departure Latitude  Departure Longitude  \
# 0                  B6740  Economy           34.438416           108.760946
# 1                  B6570  Economy           22.639444           113.810833
# 2                  B6245  Economy           34.438416           108.760946
# 3                  B6958  Economy           38.961020           121.539991
# 4                  B1681  Economy           34.438416           108.760946
# 5                  B30EU  Economy           31.197790           121.333473
# 6                  B6067  Economy           34.438416           108.760946
# 7                  B309W  Economy           23.387862           113.297340
# 8                  B32AV  Economy           31.197790           121.333473
# 9                  B2695  Economy           23.387862           113.297340
# 10                 B6977  Economy           34.438416           108.760946
# 11                 B2287  Economy           34.438416           108.760946
# 12                 B301G  Economy           41.634992           123.485731
# 13                 B323F  Economy           34.438416           108.760946
# 14                 B1843  Economy           39.508611           116.410833
# 15                 B8360  Economy           34.438416           108.760946
# 16                 TCLJG  Economy           23.387862           113.297340
# 17                 TCLSZ  Economy           41.260278            28.741944
# 18                 HBJBE  Economy           46.229634             6.105774
# 19                 ECMPS  Economy           38.770043            -9.128165
# 20                 OEIVF  Economy           40.886111            14.291667
# 21                 TCLOB  Economy           46.229634             6.105774
# 22                 TCLJA  Economy           41.260278            28.741944
# 23                 B6097  Economy           40.078538           116.587095
# 24                 B8956  Economy           31.197790           121.333473
# 25                 B919A  Economy           34.438416           108.760946
# 26                 B919A  Economy           31.197790           121.333473
# 27                 B8595  Economy           34.438416           108.760946
# 28                 TCLJG  Economy           31.143333           121.805278
# 29                 TCLSZ  Economy           41.260278            28.741944
# 30                 HBJYA  Economy           46.229634             6.105774
# 31                 HALGM  Economy           48.119720            16.563583
# 32                 HBJXB  Economy           43.660488             7.205232
#
#     Arrival Latitude  Arrival Longitude     Route Distance  No. flight
# 0          22.639444         113.810833  XIY->SZX  1397 km           2
# 1          34.438416         108.760946  SZX->XIY  1397 km           1
# 2          38.961020         121.539991  XIY->DLC  1245 km           2
# 3          34.438416         108.760946  DLC->XIY  1245 km           1
# 4          31.197790         121.333473  XIY->SHA  1229 km           2
# 5          34.438416         108.760946  SHA->XIY  1229 km           3
# 6          22.011788         113.370601  XIY->ZUH  1449 km           1
# 7          30.236934         120.432356  CAN->HGH  1038 km           1
# 8          23.387862         113.297340  SHA->CAN  1174 km           1
# 9          34.438416         108.760946  CAN->XIY  1301 km           1
# 10         39.508611         116.410833  XIY->PKX   882 km           2
# 11         38.961020         121.539991  XIY->DLC  1245 km           2
# 12         34.438416         108.760946  SHE->XIY  1516 km           1
# 13         39.508611         116.410833  XIY->PKX   882 km           2
# 14         34.438416         108.760946  PKX->XIY   882 km           1
# 15         22.639444         113.810833  XIY->SZX  1397 km           2
# 16         41.260278          28.741944  CAN->IST  7897 km           1
# 17         46.229634           6.105774  IST->GVA  1897 km           2
# 18         38.770043          -9.128165  GVA->LIS  1497 km           1
# 19         40.490270          -3.564479  LIS->MAD   514 km           1
# 20         46.229634           6.105774  NAP->GVA   887 km           1
# 21         41.260278          28.741944  GVA->IST  1897 km           1
# 22         40.078538         116.587095  IST->PEK  7078 km           1
# 23         31.197790         121.333473  PEK->SHA  1074 km           1
# 24         34.438416         108.760946  SHA->XIY  1229 km           3
# 25         31.197790         121.333473  XIY->SHA  1229 km           2
# 26         34.438416         108.760946  SHA->XIY  1229 km           3
# 27         31.143333         121.805278  XIY->PVG  1274 km           1
# 28         41.260278          28.741944  PVG->IST  8039 km           1
# 29         46.229634           6.105774  IST->GVA  1897 km           2
# 30         47.433037          19.261621  GVA->BUD  1011 km           1
# 31         43.660488           7.205232  VIE->NCE   878 km           1
# 32         46.229634           6.105774  NCE->GVA   298 km           1

# %%
my_flights_df.columns = ['Date', 'Flight Number', 'Departure', 'Arrival', 'Aircraft',
       'Tail Number', 'Class', 'Departure Latitude',
       'Departure Longitude', 'Arrival Latitude', 'Arrival Longitude', 'Route',
       'Distance', 'No. flight']

# %%
airlines = pd.read_json('./data/Airlines/airlines.json')
airlines.head()
# Out:
#                  name code  is_lowcost                                   logo
# 0          Riyadh Air   RX       False  https://pics.avs.io/200/200/RX@2x.png
# 1     Lanmei Airlines   LQ       False  https://pics.avs.io/200/200/LQ@2x.png
# 2          Air Uganda   U7       False  https://pics.avs.io/200/200/U7@2x.png
# 3  Cubana de Aviación   CU       False  https://pics.avs.io/200/200/CU@2x.png
# 4     Jonika Airlines   JO       False  https://pics.avs.io/200/200/JO@2x.png

# %%
code2fullname = dict(zip(airlines.code, airlines.name))
code2logo = dict(zip(airlines.code, airlines.logo))
my_flights_df['Airlines'] = my_flights_df['Flight Number'].str[:2].apply(lambda x: code2fullname[x])
my_flights_df['Airlines logo'] = my_flights_df['Flight Number'].str[:2].apply(lambda x: code2logo[x])
my_flights_df['Airlines logo'] = "<img src=\"" + my_flights_df['Airlines logo'] + "\" alt=\"" +my_flights_df['Airlines']+ " Logo\" width=\"50\" height=\"50\">"

# %%
my_flights_df[['Airlines','Airlines logo']].to_html(escape=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Airlines</th>\n      <th>Airlines logo</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Shenzhen Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/ZH@2x.png" alt="Shenzhen Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Shenzhen Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/ZH@2x.png" alt="Shenzhen Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Beijing Capital Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/JD@2x.png" alt="Beijing Capital Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Beijing Capital Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/JD@2x.png" alt="Beijing Capital Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Juneyao Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/HO@2x.png" alt="Juneyao Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Spring Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/9C@2x.png" alt="Spring Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>China Southern Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/CZ@2x.png" alt="China Southern Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>China Southern Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/CZ@2x.png" alt="China Southern Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>China Southern Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/CZ@2x.png" alt="China Southern Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>China Southern Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/CZ@2x.png" alt="China Southern Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>China Southern Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/CZ@2x.png" alt="China Southern Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>China Southern Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/CZ@2x.png" alt="China Southern Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>China Southern Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/CZ@2x.png" alt="China Southern Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>China Southern Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/CZ@2x.png" alt="China Southern Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>China Southern Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/CZ@2x.png" alt="China Southern Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>15</th>\n      <td>China Southern Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/CZ@2x.png" alt="China Southern Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>16</th>\n      <td>Turkish Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/TK@2x.png" alt="Turkish Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>17</th>\n      <td>Turkish Airlines</td>\n      <td><img src="https://pics.avs.io/200/200/TK@2x.png" alt="Turkish Airlines Logo" width="50" height="50"></td>\n    </tr>\n    <tr>\n      <th>18</th>\n      <td>Swiss International Air Lines</td>\n      <td><img src="https://pics.avs.io/200/200/LX@2x.png" alt="Swiss International Air Lines Logo" width="50" height="50"></td>\n    </tr>\n    <tr ...

# %%
my_flights_df[['Date', 'Airlines', 'Flight Number', 'Departure', 'Arrival', 'Aircraft',
       'Tail Number', 'Distance']].to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Date</th>\n      <th>Airlines</th>\n      <th>Flight Number</th>\n      <th>Departure</th>\n      <th>Arrival</th>\n      <th>Aircraft</th>\n      <th>Tail Number</th>\n      <th>Distance</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>2015-07-28</td>\n      <td>Shenzhen Airlines</td>\n      <td>ZH9250</td>\n      <td>XIY</td>\n      <td>SZX</td>\n      <td>Airbus A320</td>\n      <td>B6740</td>\n      <td>1397 km</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>2015-08-01</td>\n      <td>Shenzhen Airlines</td>\n      <td>ZH9249</td>\n      <td>SZX</td>\n      <td>XIY</td>\n      <td>Airbus A320</td>\n      <td>B6570</td>\n      <td>1397 km</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2019-07-25</td>\n      <td>Beijing Capital Airlines</td>\n      <td>JD5343</td>\n      <td>XIY</td>\n      <td>DLC</td>\n      <td>Airbus A319</td>\n      <td>B6245</td>\n      <td>1245 km</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>2019-07-30</td>\n      <td>Beijing Capital Airlines</td>\n      <td>JD5344</td>\n      <td>DLC</td>\n      <td>XIY</td>\n      <td>Airbus A320</td>\n      <td>B6958</td>\n      <td>1245 km</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>2022-11-03</td>\n      <td>Juneyao Airlines</td>\n      <td>HO1212</td>\n      <td>XIY</td>\n      <td>SHA</td>\n      <td>Airbus A320</td>\n      <td>B1681</td>\n      <td>1229 km</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>2022-11-09</td>\n      <td>Spring Airlines</td>\n      <td>9C8947</td>\n      <td>SHA</td>\n      <td>XIY</td>\n      <td>Airbus A321</td>\n      <td>B30EU</td>\n      <td>1229 km</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>2023-04-13</td>\n      <td>China Southern Airlines</td>\n      <td>CZ3762</td>\n      <td>XIY</td>\n      <td>ZUH</td>\n      <td>Boeing 737</td>\n      <td>B6067</td>\n      <td>1449 km</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>2023-04-17</td>\n      <td>China Southern Airlines</td>\n      <td>CZ6567</td>\n      <td>CAN</td>\n      <td>HGH</td>\n      <td>Airbus A350</td>\n      <td>B309W</td>\n      <td>1038 km</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>2023-04-24</td>\n      <td>China Southern Airlines</td>\n      <td>CZ3548</td>\n      <td>SHA</td>\n      <td>CAN</td>\n      <td>Airbus A350</td>\n      <td>B32AV</td>\n      <td>1174 km</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>2023-04-24</td>\n      <td>China Southern Airlines</td>\n      <td>CZ3215</td>\n      <td>CAN</td>\n      <td>XIY</td>\n      <td>Boeing 737</td>\n      <td>B2695</td>\n      <td>1301 km</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>2023-05-09</td>\n      <td>China Southern Airlines</td>\n      <td>CZ8830</td>\n      <td>XIY</td>\n      <td>PKX</td>\n      <td>Airbus A320</td>\n      <td>B6977</td>\n      <td>882 km</td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>2023-06-19</td>\n      <td>China Southern Airlines</td>\n      <td>CZ6938</td>\n      <td>XIY</td>\n      <td>DLC</td>\n      <td>Airbus A321</td>\n      <td>B2287</td>\n      <td>1245 km</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>2023-06-26</td>\n      <td>China Southern Airlines</td>\n      <td>CZ6415</td>\n      <td>SHE</td>\n      <td>XIY</td>\n      <td>Airbus A320</td>\n      <td>B301G</td>\n      <td>1516 km</td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>2023-07-04</td>\n      <td>China Southern Airlines</td>\n      <td>CZ8830</td>\n      <td>XIY</td>\n      <td>PKX</td>\n      <td>Airbus A321</td>\n      <td>B323F</td>\n      <td>882 km</td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>2023-07-06</td>\n      <td>China Southern Airlines</td>\n      <td>CZ6948</td>\n      <td>PKX</td>\n      <td>XIY</td>\n      <td>Airbus A321</td>\n      <td>B1843</td>\n      <td>882 km</td>\n    </tr>\n    <tr>\n      <th>15</th>\n      <td ...

# %%
airline_counts = my_flights_df.groupby('Airlines',as_index=False).count().iloc[:,[0,1]]
airline_counts.columns = [' ','Flights']
airline_counts['Airline'] = my_flights_df.groupby('Airlines',as_index=False).apply(lambda x : x['Airlines logo']).unique()

# %%
airline_counts = airline_counts.sort_values(by='Flights',ascending=False).set_index('Airline')

# %%
airline_counts.to_html(escape=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th></th>\n      <th>Flights</th>\n    </tr>\n    <tr>\n      <th>Airline</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th><img src="https://pics.avs.io/200/200/CZ@2x.png" alt="China Southern Airlines Logo" width="50" height="50"></th>\n      <td>China Southern Airlines</td>\n      <td>10</td>\n    </tr>\n    <tr>\n      <th><img src="https://pics.avs.io/200/200/TK@2x.png" alt="Turkish Airlines Logo" width="50" height="50"></th>\n      <td>Turkish Airlines</td>\n      <td>6</td>\n    </tr>\n    <tr>\n      <th><img src="https://pics.avs.io/200/200/MU@2x.png" alt="China Eastern Airlines Logo" width="50" height="50"></th>\n      <td>China Eastern Airlines</td>\n      <td>3</td>\n    </tr>\n    <tr>\n      <th><img src="https://pics.avs.io/200/200/U2@2x.png" alt="EasyJet Logo" width="50" height="50"></th>\n      <td>EasyJet</td>\n      <td>3</td>\n    </tr>\n    <tr>\n      <th><img src="https://pics.avs.io/200/200/JD@2x.png" alt="Beijing Capital Airlines Logo" width="50" height="50"></th>\n      <td>Beijing Capital Airlines</td>\n      <td>2</td>\n    </tr>\n    <tr>\n      <th><img src="https://pics.avs.io/200/200/HO@2x.png" alt="Juneyao Airlines Logo" width="50" height="50"></th>\n      <td>Juneyao Airlines</td>\n      <td>2</td>\n    </tr>\n    <tr>\n      <th><img src="https://pics.avs.io/200/200/ZH@2x.png" alt="Shenzhen Airlines Logo" width="50" height="50"></th>\n      <td>Shenzhen Airlines</td>\n      <td>2</td>\n    </tr>\n    <tr>\n      <th><img src="https://pics.avs.io/200/200/CA@2x.png" alt="Air China Logo" width="50" height="50"></th>\n      <td>Air China</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th><img src="https://pics.avs.io/200/200/UX@2x.png" alt="Air Europa Logo" width="50" height="50"></th>\n      <td>Air Europa</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th><img src="https://pics.avs.io/200/200/9C@2x.png" alt="Spring Airlines Logo" width="50" height="50"></th>\n      <td>Spring Airlines</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th><img src="https://pics.avs.io/200/200/LX@2x.png" alt="Swiss International Air Lines Logo" width="50" height="50"></th>\n      <td>Swiss International Air Lines</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th><img src="https://pics.avs.io/200/200/W4@2x.png" alt="Wizz Air Logo" width="50" height="50"></th>\n      <td>Wizz Air</td>\n      <td>1</td>\n    </tr>\n  </tbody>\n</table>'

# %%
aircraft_counts = my_flights_df.groupby('Aircraft',as_index=False).count().iloc[:,[0,1]]
aircraft_counts.columns = [' ','Flights']
com2con = {'Airbus':'eu', 'Boeing':'us', 'COMAC': 'cn'}

aircraft_counts['Aircraft'] = [com2con[i[0]] for i in aircraft_counts[' '].str.split()]
aircraft_counts['Aircraft'] = "<img src=\"./assets/images/flagicons/" + aircraft_counts['Aircraft'] + ".svg\" width=\"30\" height=\"30\">"

# %%
aircraft_counts = aircraft_counts.sort_values(by='Flights',ascending=False).set_index('Aircraft')

# %%
aircraft_counts.to_html(escape=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th></th>\n      <th>Flights</th>\n    </tr>\n    <tr>\n      <th>Aircraft</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th><img src="./assets/images/flagicons/eu.svg" width="30" height="30"></th>\n      <td>Airbus A320</td>\n      <td>9</td>\n    </tr>\n    <tr>\n      <th><img src="./assets/images/flagicons/eu.svg" width="30" height="30"></th>\n      <td>Airbus A321</td>\n      <td>9</td>\n    </tr>\n    <tr>\n      <th><img src="./assets/images/flagicons/eu.svg" width="30" height="30"></th>\n      <td>Airbus A330</td>\n      <td>3</td>\n    </tr>\n    <tr>\n      <th><img src="./assets/images/flagicons/us.svg" width="30" height="30"></th>\n      <td>Boeing 737</td>\n      <td>3</td>\n    </tr>\n    <tr>\n      <th><img src="./assets/images/flagicons/us.svg" width="30" height="30"></th>\n      <td>Boeing 777</td>\n      <td>3</td>\n    </tr>\n    <tr>\n      <th><img src="./assets/images/flagicons/eu.svg" width="30" height="30"></th>\n      <td>Airbus A350</td>\n      <td>2</td>\n    </tr>\n    <tr>\n      <th><img src="./assets/images/flagicons/cn.svg" width="30" height="30"></th>\n      <td>COMAC C919</td>\n      <td>2</td>\n    </tr>\n    <tr>\n      <th><img src="./assets/images/flagicons/eu.svg" width="30" height="30"></th>\n      <td>Airbus A220</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th><img src="./assets/images/flagicons/eu.svg" width="30" height="30"></th>\n      <td>Airbus A319</td>\n      <td>1</td>\n    </tr>\n  </tbody>\n</table>'
